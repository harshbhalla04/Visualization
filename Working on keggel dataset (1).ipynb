# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df1=pd.read_csv('World University Rankings 2023.csv')
df1.dropna(inplace=True)

# %%
df1
# Out:
#      University Rank                     Name of University        Location  \
# 0                  1                   University of Oxford  United Kingdom
# 1                  2                     Harvard University   United States
# 2                  3                University of Cambridge  United Kingdom
# 3                  3                    Stanford University   United States
# 4                  5  Massachusetts Institute of Technology   United States
# ...              ...                                    ...             ...
# 2336               -     University of the West of Scotland             NaN
# 2337               -                  University of Windsor             NaN
# 2338               -            University of Wolverhampton             NaN
# 2339               -                University of Wuppertal             NaN
# 2340               -    Xi’an Jiaotong-Liverpool University             NaN
#
# ...

# %%
df1.head()
# Out:
#   University Rank                     Name of University        Location  \
# 0               1                   University of Oxford  United Kingdom
# 1               2                     Harvard University   United States
# 2               3                University of Cambridge  United Kingdom
# 3               3                    Stanford University   United States
# 4               5  Massachusetts Institute of Technology   United States
#
#   No of student  No of student per staff International Student  \
# 0        20,965                     10.6                   42%
# 1        21,887                      9.6                   25%
# 2        20,185                     11.3                   39%
# 3        16,164                      7.1                   24%
# 4        11,415                      8.2                   33%
#
#   Female:Male Ratio OverAll Score  Teaching Score  Research Score  \
# 0           48 : 52          96.4            92.3            99.7
# ...

# %% [raw]
# 1. Show the names of top 10 university in world
# 2. show the names of bottom 10 university in world
# 3. show top 5 university of india
# 4. show the university of india ranked in top 500

# %%
# 1. Show the names of top 1df1[0 university in world
df1['Name of University'].head(10)
# Out:
# 0                     University of Oxford
# 1                       Harvard University
# 2                  University of Cambridge
# 3                      Stanford University
# 4    Massachusetts Institute of Technology
# 5       California Institute of Technology
# 6                     Princeton University
# 7       University of California, Berkeley
# 8                          Yale University
# 9                  Imperial College London
# Name: Name of University, dtype: object

# %%
# 2. show the names of bottom 10 university in world
df1['Name of University'].tail(10)
# Out:
# 1686    Vietnam National University (Ho Chi Minh City)
# 1688                               Walailak University
# 1689        University of Warmia and Mazury in Olsztyn
# 1690                         University of West Attica
# 1691                      West University of Timişoara
# 1692      Wrocław University of Science and Technology
# 1693                              Yamaguchi University
# 1694                                Yanshan University
# 1695                               Yeditepe University
# 1696                Zonguldak Bülent Ecevit University
# Name: Name of University, dtype: object

# %%
# 3. show top 5 university of india
df1[df1['Location']=='India']['Name of University'].head()
# Out:
# 271                          Indian Institute of Science
# 369         JSS Academy of Higher Education and Research
# 386    Shoolini University of Biotechnology and Manag...
# 397                                  Alagappa University
# 449                            Mahatma Gandhi University
# Name: Name of University, dtype: object

# %%
# 4. show the university of india ranked in top 500
df1[(df1['Location']=='India')&(df1.index<=500)]
# Out:
#     University Rank                                 Name of University  \
# 271         251–300                        Indian Institute of Science
# 369         351–400       JSS Academy of Higher Education and Research
# 386         351–400  Shoolini University of Biotechnology and Manag...
# 397         401–500                                Alagappa University
# 449         401–500                          Mahatma Gandhi University
#
#     Location No of student  No of student per staff International Student  \
# 271    India         3,990                      8.8                    1%
# 369    India         7,891                      9.5                    7%
# 386    India         2,973                     14.3                    2%
# 397    India         4,831                     15.7                    0%
# 449    India         1,855                     14.6                    2%
#
#     Female:Male Ratio OverAll Score  Teaching Score  Research Score  \
# ...

# %% [raw]
# 1. Show the top 5 university with max No of student per staff
# 2. Show the top 10 university with higest Industry Income Score
# 3. Show the top 5 university with max No of student

# %%
df1.sort_values(by='No of student per staff',ascending=False).head()

# %%
df1
# Out:
#      University Rank                            Name of University  \
# 0                  1                          University of Oxford
# 1                  2                            Harvard University
# 2                  3                       University of Cambridge
# 3                  3                           Stanford University
# 4                  5         Massachusetts Institute of Technology
# ...              ...                                           ...
# 1692           1501+  Wrocław University of Science and Technology
# 1693           1501+                          Yamaguchi University
# 1694           1501+                            Yanshan University
# 1695           1501+                           Yeditepe University
# 1696           1501+            Zonguldak Bülent Ecevit University
#
#             Location No of student  No of student per staff  \
# 0     United Kingdom        20,965                     10.6
# ...

# %%
df1.sort_values(by='No of student per staff',ascending=False)[['Name of University','No of student per staff']].head()
# Out:
#                                      Name of University  \
# 1121                         University of South Africa
# 1626                             Payame Noor University
# 560                        Open University of Catalonia
# 1160                      Abdelmalek Essaâdi University
# 1054  Kwame Nkrumah University of Science and Techno...
#
#       No of student per staff
# 1121                    232.2
# 1626                    124.7
# 560                     100.5
# 1160                     88.2
# 1054                     78.1

# %%
df1.sort_values(by='Industry Income Score',ascending=False)[['Name of University','Industry Income Score']].head(5)
# Out:
#                                    Name of University  Industry Income Score
# 91  Korea Advanced Institute of Science and Techno...                  100.0
# 15                                Tsinghua University                  100.0
# 32                                         LMU Munich                  100.0
# 29                     Technical University of Munich                  100.0
# 66                                Zhejiang University                  100.0

# %%
# 1. Show the top 5 university with max number of students
df1.sort_values(by='No of student per staff',ascending=False)[['Name of University','Location']].head()
# Out:
#                                      Name of University      Location
# 1121                         University of South Africa  South Africa
# 1626                             Payame Noor University          Iran
# 560                        Open University of Catalonia         Spain
# 1160                      Abdelmalek Essaâdi University       Morocco
# 1054  Kwame Nkrumah University of Science and Techno...         Ghana

# %%
# 2. Show the top 10 university with higest Industry Income Score
df1.sort_values(by='Industry Income Score',ascending=False)[['Name of University','Industry Income Score']].head(10)
# Out:
#                                     Name of University  Industry Income Score
# 58                    Wageningen University & Research                  100.0
# 675                      Istanbul Technical University                  100.0
# 91   Korea Advanced Institute of Science and Techno...                  100.0
# 442                                     Koç University                  100.0
# 51                       Shanghai Jiao Tong University                  100.0
# 550                   Middle East Technical University                   99.9
# 902                 Universiti Pendidikan Sultan Idris                   99.9
# 24                                     Duke University                   99.6
# 100                                University of Basel                   99.2
# 324                                  Nagoya University                   99.2

# %%
df1['No of student']
# Out:
# 0       20,965
# 1       21,887
# 2       20,185
# 3       16,164
# 4       11,415
#          ...
# 1692    23,657
# 1693    10,724
# 1694    38,649
# 1695    17,038
# 1696    28,319
# Name: No of student, Length: 1488, dtype: object

# %%
def co(n):
    return n.replace(',','')

# %%
df1['No of student']=df1['No of student'].apply(co)

# %%
df1['No of student']=df1['No of student'].astype(int)

# %%
df1.dtypes
# Out:
# University Rank                 object
# Name of University              object
# Location                        object
# No of student                    int32
# No of student per staff        float64
# International Student           object
# Female:Male Ratio               object
# OverAll Score                   object
# Teaching Score                 float64
# Research Score                 float64
# Citations Score                float64
# Industry Income Score          float64
# International Outlook Score    float64
# dtype: object

# %%
df1.sort_values(by='No of student',ascending=False)[['Name of University','No of student']].head()
# Out:
#               Name of University  No of student
# 944         Tribhuvan University         460632
# 1626      Payame Noor University         454155
# 770          Al-Azhar University         425977
# 1121  University of South Africa         236282
# 794             Cairo University         224216

# %%
a='34,567'
a.replace(',','')
# Out:
# '34567'

# %%
def comma(s):
    return s.replace(',','')

# %%
comma('34,5543')
# Out:
# '345543'

# %%
(lambda s: s.replace(',',''))('34,567')
# Out:
# '34567'

# %%
df1['No of student']=df1['No of student'].apply(comma)

# %%
# 3. Show the top 5 university with max No of student
df1['No of student']=df1['No of student'].astype(int)

# %%
df1['No of student'].dtype
# Out:
# dtype('int32')

# %%
df1.sort_values(by='No of student',ascending=False)[['Name of University','No of student']].head()
# Out:
#               Name of University  No of student
# 944         Tribhuvan University         460632
# 1626      Payame Noor University         454155
# 770          Al-Azhar University         425977
# 1121  University of South Africa         236282
# 794             Cairo University         224216

# %% [raw]
# 1. Show the university more than 60% international student
# 2. Show the university with more female than males

# %%
# 1. Show the university more than 60% international stude
def per(s):
    return s.replace('%','')

# %%
df1['International Student']=df1['International Student'].apply(per)
df1
# Out:
#      University Rank                            Name of University  \
# 0                  1                          University of Oxford
# 1                  2                            Harvard University
# 2                  3                       University of Cambridge
# 3                  3                           Stanford University
# 4                  5         Massachusetts Institute of Technology
# ...              ...                                           ...
# 1692           1501+  Wrocław University of Science and Technology
# 1693           1501+                          Yamaguchi University
# 1694           1501+                            Yanshan University
# 1695           1501+                           Yeditepe University
# 1696           1501+            Zonguldak Bülent Ecevit University
#
#             Location  No of student  No of student per staff  \
# 0     United Kingdom          20965                     10.6
# ...

# %%
df1.loc[df1['International Student']=='','International Student']=0

# %%
df1['International Student']=df1['International Student'].astype(int)

# %%
df1[df1['International Student']>=60][['Name of University','International Student']]
# Out:
#                                    Name of University  International Student
# 9                             Imperial College London                     61
# 21                                                UCL                     60
# 36   London School of Economics and Political Science                     73
# 40           École Polytechnique Fédérale de Lausanne                     62
# 237                Università della Svizzera italiana                     66
# 299                              Abu Dhabi University                     60
# 512                  Eastern Mediterranean University                     76
# 525                      Hong Kong Baptist University                     62
# 601                    American University of Sharjah                     76
# 724                              Near East University                     83

# %%
# 2. Show the university with more female than males

# %%
df1['Female_ratio']=df1['Female:Male Ratio'].str.split(expand=True)[0]

# %%
df1.head()
# Out:
#   University Rank                     Name of University        Location  \
# 0               1                   University of Oxford  United Kingdom
# 1               2                     Harvard University   United States
# 2               3                University of Cambridge  United Kingdom
# 3               3                    Stanford University   United States
# 4               5  Massachusetts Institute of Technology   United States
#
#   No of student  No of student per staff International Student  \
# 0        20,965                     10.6                   42%
# 1        21,887                      9.6                   25%
# 2        20,185                     11.3                   39%
# 3        16,164                      7.1                   24%
# 4        11,415                      8.2                   33%
#
#   Female:Male Ratio OverAll Score  Teaching Score  Research Score  \
# 0           48 : 52          96.4            92.3            99.7
# ...

# %%
df1['Female Ratio']=df1['Female:Male Ratio'].str.split(expand=True)[0]

# %%
df1
# Out:
#      University Rank                     Name of University        Location  \
# 0                  1                   University of Oxford  United Kingdom
# 1                  2                     Harvard University   United States
# 2                  3                University of Cambridge  United Kingdom
# 3                  3                    Stanford University   United States
# 4                  5  Massachusetts Institute of Technology   United States
# ...              ...                                    ...             ...
# 2336               -     University of the West of Scotland             NaN
# 2337               -                  University of Windsor             NaN
# 2338               -            University of Wolverhampton             NaN
# 2339               -                University of Wuppertal             NaN
# 2340               -    Xi’an Jiaotong-Liverpool University             NaN
#
# ...

# %%
df1.dtypes
# Out:
# University Rank                 object
# Name of University              object
# Location                        object
# No of student                    int32
# No of student per staff        float64
# International Student           object
# Female:Male Ratio               object
# OverAll Score                   object
# Teaching Score                 float64
# Research Score                 float64
# Citations Score                float64
# Industry Income Score          float64
# International Outlook Score    float64
# Female Ratio                    object
# dtype: object

# %%
df1['Female Ratio']=df1['Female Ratio'].astype(int)

# %%
df1.dtypes
# Out:
# University Rank                 object
# Name of University              object
# Location                        object
# No of student                    int32
# No of student per staff        float64
# International Student           object
# Female:Male Ratio               object
# OverAll Score                   object
# Teaching Score                 float64
# Research Score                 float64
# Citations Score                float64
# Industry Income Score          float64
# International Outlook Score    float64
# Female Ratio                     int32
# dtype: object

# %%
df1['Female_ratio']=df1['Female_ratio'].astype(int)

# %%
df1[df1['Female Ratio']>=50][['Name of University']]
# Out:
#                               Name of University
# 1                             Harvard University
# 7             University of California, Berkeley
# 8                                Yale University
# 13                    University of Pennsylvania
# 14                      Johns Hopkins University
# ...                                          ...
# 1684                    University of Valparaíso
# 1688                         Walailak University
# 1689  University of Warmia and Mazury in Olsztyn
# 1691                West University of Timişoara
# 1695                         Yeditepe University
#
# [944 rows x 1 columns]

# %%
df1[df1['Female_ratio']>50][['Name of University','Female_ratio']]
# Out:
#                               Name of University  Female_ratio
# 7             University of California, Berkeley            52
# 8                                Yale University            52
# 13                    University of Pennsylvania            53
# 14                      Johns Hopkins University            53
# 17                         University of Toronto            56
# ...                                          ...           ...
# 1684                    University of Valparaíso            58
# 1688                         Walailak University            73
# 1689  University of Warmia and Mazury in Olsztyn            59
# 1691                West University of Timişoara            66
# 1695                         Yeditepe University            55
#
# [895 rows x 2 columns]

# %%
# 3. What is the percentage of indian university in data

# %%
(df1[df1['Location']=='India'].shape[0]/df1.shape[0])*100
# Out:
# 4.368279569892473

# %%
# Vizualization

# %% [raw]
# --> Category and number
# --> Number: histogram, dist plot, box plot
# --> Category: count plot\bar, pie chart
# --> Number vs number: scatter plot, reg-plot
# --> Number vs category: Box plot, strip plot, swarm plot, violin plot
# --> Category vs category: crosstab, group bar plot
# --> Category vs number ( hue category): strip plot,grouped Bar, swarm plot,violen plot(hue the third category)
# --> Number vs number ( hue category): scatter plot (hue the third category)
# --> Series data:line,area plot

# %% [raw]
# 1. Show the distibution in number of students

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
sns.distplot(df1['No of student'])
plt.show()

# %% [raw]
# 2. Display the count of data in top 5 location

# %%
sns.countplot(data=df1,x='Location')
# Out:
# <Axes: xlabel='Location', ylabel='count'>

# %%
df1['Location'].value_counts().head().plot(kind='bar')
plt.show()

# %%
df1['Location'].value_counts().head().plot(kind='pie',autopct='%0.2f%%')
plt.show()

# %%
mpg =  sns.load_dataset('mpg')

# %%
mpg
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0       130.0    3504          12.0
# 1    15.0          8         350.0       165.0    3693          11.5
# 2    18.0          8         318.0       150.0    3436          11.0
# 3    16.0          8         304.0       150.0    3433          12.0
# 4    17.0          8         302.0       140.0    3449          10.5
# ..    ...        ...           ...         ...     ...           ...
# 393  27.0          4         140.0        86.0    2790          15.6
# 394  44.0          4          97.0        52.0    2130          24.6
# 395  32.0          4         135.0        84.0    2295          11.6
# 396  28.0          4         120.0        79.0    2625          18.6
# 397  31.0          4         119.0        82.0    2720          19.4
#
#      model_year  origin                       name
# 0            70     usa  chevrolet chevelle malibu
# ...

# %%
# show the distribution of cylinder

# %%
mpg.cylinders.value_counts()
# Out:
# 4    204
# 8    103
# 6     84
# 3      4
# 5      3
# Name: cylinders, dtype: int64

# %%
sns.countplot(data=mpg,x='cylinders')
# Out:
# <Axes: xlabel='cylinders', ylabel='count'>

# %%
# pie chart of above question

# %%
# show a chart how the mpg is affected by the no of cylinder

# %%
sns.boxplot(data=mpg,x='cylinders',y='mpg')
# Out:
# <Axes: xlabel='cylinders', ylabel='mpg'>

# %%
sns.stripplot(data = mpg,x='cylinders',y='mpg')
# Out:
# <Axes: xlabel='cylinders', ylabel='mpg'>

# %%
# how mpg is affacted by engine capacity(Displacement)

# %%
plt.scatter(x=mpg['mpg'],y=mpg['displacement'])
plt.show()

# %%
sns.regplot(x=mpg['mpg'],y=mpg['displacement'],line_kws={'color':'red'})
# Out:
# <Axes: xlabel='mpg', ylabel='displacement'>

# %%
# show that how many cylinder cars from each origin?

# %%
pd.crosstab(index=mpg['origin'],columns=mpg['cylinders'],values=mpg['mpg'],aggfunc='mean').plot(kind='bar')
# Out:
# <Axes: xlabel='origin'>

# %%
# Show the chart how mpg is affacted by no of cylinders in each origin

# %%
sns.swarmplot(data=mpg,x='cylinders',y='mpg',hue='origin')
# Out:
# <Axes: xlabel='cylinders', ylabel='mpg'>

# %%
# how mpg is affacted by engine capacity(Displacement) and number of cylinder

# %%
sns.scatterplot(data=mpg,x='displacement',y='mpg',hue='cylinders',palette=['green','blue','red','magenta','cyan'])
# Out:
# <Axes: xlabel='displacement', ylabel='mpg'>
